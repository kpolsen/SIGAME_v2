# %% [markdown]
# # Tutorial 3: Datacube creation step

# %% [markdown]
# ### Before importing SIGAME
# As in the previous tutorials, we first make sure to select the relevant task, here `datacubes`, in parameters_z0.txt:
# ```
# BACKEND TASKS
# -1 extract_galaxy
# -1 subgrid
# -1 interpolate
# +1 datacubes
# FRONTEND TASKS
# -1 regions
# -1 PCR_analysis
# ```
# Make any necessary edits to parameters_z0.txt, save, and you're good to go!

# %%
import sigame as si
# Out:
#    =======================================================
#
#    .oOOOo.  ooOoOOo  .oOOOo.     Oo    Oo      oO o.OOoOoo
#    o     o     O    .O     o    o  O   O O    o o  O
#    O.          o    o          O    o  o  o  O  O  o
#     `OOoo.     O    O         oOooOoOo O   Oo   O  ooOO
#          `O    o    O   .oOOo o      O O        o  O
#           o    O    o.      O O      o o        O  o
#    O.    .O    O     O.    oO o      O o        O  O
#     `oooO'  ooOOoOo   `OooO'  O.     O O        o ooOooOoO
#
#    =======================================================
#     SImulator of GAlaxy Millimeter/submillimeter Emission
# -- A code to simulate the far-IR emission lines of the ISM  --
# ----------- in galaxies from hydrodynamical codes ------------
# --- for the interpretation and prediction of observations. ---
# -- Contact: Karen Pardos Olsen, kpolsen (at) asu.edu (2018) --
#
#
# At which redshift? (default: 0)0
# Reading parameter file: [parameters_z0.txt] ...
#
# will look for code in /home/karen/code/astro/sigame_release/sigame/
# will look for cloudy data in /home/karen/code/astro/sigame_release/sigame/temp/z0_data_files/
#
#
#                  Parameters chosen
# +--------------------+----------+---------------+--------------------------------------------------+
# |     Parameter      |  Value   |  Name in code |                   Explanation                    |
# +--------------------+----------+---------------+--------------------------------------------------+
# |   Repr. redshift   |         0|      zred     |         Redshift of simulation snapshot          |
# |     # galaxies     |         1|      nGal     |      Number of galaxies in redshift sample       |
# | Dense cloudy grid  |     _abun|   ext_DENSE   |       Extension of desired GMC model grid        |
# |Diffuse cloudy grid |     _abun|  ext_DIFFUSE  |       Extension of desired HIM model grid        |
# |   Fraction of h    |       0.5|     frac_h    |        GMCs are distributed < frac_h * h         |
# +--------------------+----------+---------------+--------------------------------------------------+
#
# This is what sigame.run() is set up to do (change in parameter file):
# - Create datacubes for ISM phases GMC, DNG and DIG
#
# --------------------------------------------------------------
#
# Ready to continue!

# %%
si.run()
# Out:
#  Number of galaxies in selection: 1
# ** This is the main controller running SIGAME for the given galaxy sample **
#
# --- Datacube creation ---
# Check which datacubes we're doing...
# Overwrite is ON
# sigame/temp/z0_data_files/particle_data/ISM_data/z0.00_h401_s135_G2_GMC.h5
# sigame/temp/z0_data_files/particle_data/ISM_data/z0.00_h401_s135_G2_dif.h5
# Index(['x', 'y', 'z', 'vx', 'vy', 'vz', 'vel_disp_gas', 'm', 'nH', 'R', 'Z',
#        'Tk', 'FUV', 'm_DNG', 'm_DIG', 'm_H_DNG', 'm_H_DIG', 'm_HI_DNG',
#        'm_HI_DIG', 'm_H2_DNG', 'm_H2_DIG', 'm_HII_DNG', 'm_HII_DIG', 'm_C_DNG',
#        'm_C_DIG', 'm_CII_DNG', 'm_CII_DIG', 'm_CIV_DNG', 'm_CIV_DIG',
#        'm_CIII_DNG', 'm_CIII_DIG', 'm_CO_DNG', 'm_CO_DIG', 'm_dust', 'Tk_DNG',
#        'Tk_DIG', 'closest_model_i', 'L_CII', 'L_CII_int', 'L_CII_DNG',
#        'L_CII_DNG_int', 'L_CII_DIG', 'L_CII_DIG_int', 'L_OI', 'L_OI_int',
#        'L_OI_DNG', 'L_OI_DNG_int', 'L_OI_DIG', 'L_OI_DIG_int', 'L_OIII',
#        'L_OIII_int', 'L_OIII_DNG', 'L_OIII_DNG_int', 'L_OIII_DIG',
#        'L_OIII_DIG_int', 'L_NII_122', 'L_NII_122_int', 'L_NII_122_DNG',
#        'L_NII_122_DNG_int', 'L_NII_122_DIG', 'L_NII_122_DIG_int', 'L_NII_205',
#        'L_NII_205_int', 'L_NII_205_DNG', 'L_NII_205_DNG_int', 'L_NII_205_DIG',
#        'L_NII_205_DIG_int', 'L_CI_609', 'L_CI_609_int', 'L_CI_609_DNG',
#        'L_CI_609_DNG_int', 'L_CI_609_DIG', 'L_CI_609_DIG_int', 'L_CI_369',
#        'L_CI_369_int', 'L_CI_369_DNG', 'L_CI_369_DNG_int', 'L_CI_369_DIG',
#        'L_CI_369_DIG_int', 'L_CO32', 'L_CO32_int', 'L_CO32_DNG',
#        'L_CO32_DNG_int', 'L_CO32_DIG', 'L_CO32_DIG_int', 'L_CO21',
#        'L_CO21_int', 'L_CO21_DNG', 'L_CO21_DNG_int', 'L_CO21_DIG',
#        'L_CO21_DIG_int', 'L_CO10', 'L_CO10_int', 'L_CO10_DNG',
#        'L_CO10_DNG_int', 'L_CO10_DIG', 'L_CO10_DIG_int', 'm_dust_DNG',
#        'm_dust_DIG'],
#       dtype='object')
#
# NOW CREATING DATACUBES OF L_CII FOR ISM PHASE DNG
#  1) Create (if not there already) radial profiles of all model clouds
# Looking for: sigame/temp/z0_data_files/cloud_profiles/rad_profs_L_CII_z0_DNG_0.1UV.npy
#  2) Load clouds in galaxy
# Total number of clouds loaded: 28026
# Total number of clouds to be drizzled: 5000
# 3) Check how many models are available
# 0 corresponding models did not finish
# out of 5000 clouds
# 4) Drizzle onto datacube
# Now drizzling 500 DNG clouds (# 0 to 499) onto galaxy grid at 0.1 x MW FUV...
# Now drizzling 500 DNG clouds (# 500 to 999) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# (Using multiprocessing on 500 clouds at a time! 2 cores in use)
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DNG clouds (# 1000 to 1499) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DNG clouds (# 1500 to 1999) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DNG clouds (# 2000 to 2499) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DNG clouds (# 2500 to 2999) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DNG clouds (# 3000 to 3499) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DNG clouds (# 3500 to 3999) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DNG clouds (# 4000 to 4499) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DNG clouds (# 4500 to 4999) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# 0 highres cloud pixels went outside galaxy image
# Time it took to do this ISM phase: 3.06 s
# L_CII = 2.15e+05 Lsun from interpolated clouds
# L_CII = 2.15e+05 Lsun from datacube (will be smaller due to missing radial profiles for models that did not run)
# Max in Lsun: 6.34e+02
# Max in Jy: 1.60e-01
# saving data h5store sigame/temp/z0_data_files/datacubes/z0_L_CII_i0_h401_s135_G2_DNG.h5
# /home/karen/code/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:2377: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->['data']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)
# sigame/temp/z0_data_files/particle_data/ISM_data/z0.00_h401_s135_G2_GMC.h5
# sigame/temp/z0_data_files/particle_data/ISM_data/z0.00_h401_s135_G2_dif.h5
# Index(['x', 'y', 'z', 'vx', 'vy', 'vz', 'vel_disp_gas', 'm', 'nH', 'R', 'Z',
#        'Tk', 'FUV', 'm_DNG', 'm_DIG', 'm_H_DNG', 'm_H_DIG', 'm_HI_DNG',
#        'm_HI_DIG', 'm_H2_DNG', 'm_H2_DIG', 'm_HII_DNG', 'm_HII_DIG', 'm_C_DNG',
#        'm_C_DIG', 'm_CII_DNG', 'm_CII_DIG', 'm_CIV_DNG', 'm_CIV_DIG',
#        'm_CIII_DNG', 'm_CIII_DIG', 'm_CO_DNG', 'm_CO_DIG', 'm_dust', 'Tk_DNG',
#        'Tk_DIG', 'closest_model_i', 'L_CII', 'L_CII_int', 'L_CII_DNG',
#        'L_CII_DNG_int', 'L_CII_DIG', 'L_CII_DIG_int', 'L_OI', 'L_OI_int',
#        'L_OI_DNG', 'L_OI_DNG_int', 'L_OI_DIG', 'L_OI_DIG_int', 'L_OIII',
#        'L_OIII_int', 'L_OIII_DNG', 'L_OIII_DNG_int', 'L_OIII_DIG',
#        'L_OIII_DIG_int', 'L_NII_122', 'L_NII_122_int', 'L_NII_122_DNG',
#        'L_NII_122_DNG_int', 'L_NII_122_DIG', 'L_NII_122_DIG_int', 'L_NII_205',
#        'L_NII_205_int', 'L_NII_205_DNG', 'L_NII_205_DNG_int', 'L_NII_205_DIG',
#        'L_NII_205_DIG_int', 'L_CI_609', 'L_CI_609_int', 'L_CI_609_DNG',
#        'L_CI_609_DNG_int', 'L_CI_609_DIG', 'L_CI_609_DIG_int', 'L_CI_369',
#        'L_CI_369_int', 'L_CI_369_DNG', 'L_CI_369_DNG_int', 'L_CI_369_DIG',
#        'L_CI_369_DIG_int', 'L_CO32', 'L_CO32_int', 'L_CO32_DNG',
#        'L_CO32_DNG_int', 'L_CO32_DIG', 'L_CO32_DIG_int', 'L_CO21',
#        'L_CO21_int', 'L_CO21_DNG', 'L_CO21_DNG_int', 'L_CO21_DIG',
#        'L_CO21_DIG_int', 'L_CO10', 'L_CO10_int', 'L_CO10_DNG',
#        'L_CO10_DNG_int', 'L_CO10_DIG', 'L_CO10_DIG_int', 'm_dust_DNG',
#        'm_dust_DIG'],
#       dtype='object')
#
# NOW CREATING DATACUBES OF L_CII FOR ISM PHASE DIG
#  1) Create (if not there already) radial profiles of all model clouds
# Looking for: sigame/temp/z0_data_files/cloud_profiles/rad_profs_L_CII_z0_DIG_0.1UV.npy
#  2) Load clouds in galaxy
# Total number of clouds loaded: 28026
# Total number of clouds to be drizzled: 5000
# 3) Check how many models are available
# 0 corresponding models did not finish
# out of 5000 clouds
# 4) Drizzle onto datacube
# Now drizzling 500 DIG clouds (# 500 to 999) onto galaxy grid at 0.1 x MW FUV...
# Now drizzling 500 DIG clouds (# 0 to 499) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# (Using multiprocessing on 500 clouds at a time! 2 cores in use)
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DIG clouds (# 1000 to 1499) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DIG clouds (# 1500 to 1999) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DIG clouds (# 2000 to 2499) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DIG clouds (# 2500 to 2999) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DIG clouds (# 3000 to 3499) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DIG clouds (# 3500 to 3999) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DIG clouds (# 4000 to 4499) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# Now drizzling 500 DIG clouds (# 4500 to 4999) onto galaxy grid at 0.1 x MW FUV...
# 0 small clouds, unresolved by galaxy pixels
# 500 large clouds, resolved by galaxy pixels
# 0 highres cloud pixels went outside galaxy image
# 0 highres cloud pixels went outside galaxy image
# Time it took to do this ISM phase: 3.03 s
# L_CII = 8.73e+05 Lsun from interpolated clouds
# L_CII = 8.73e+05 Lsun from datacube (will be smaller due to missing radial profiles for models that did not run)
# Max in Lsun: 8.50e+02
# Max in Jy: 2.15e-01
# saving data h5store sigame/temp/z0_data_files/datacubes/z0_L_CII_i0_h401_s135_G2_DIG.h5
#
# --------------------------------------------------------------
